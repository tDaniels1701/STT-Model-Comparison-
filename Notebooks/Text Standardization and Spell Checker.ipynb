# %%
import numpy as np
import string
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import sklearn.manifold as skmf
import re
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import seaborn as sns
import nltk
xl =pd.ExcelFile("Fixed 2026VC.xlsx") # feed case presentation textual excel file to reader 
#data
data1=xl.parse("Sheet1",header=0) # could skip this step for case presentation data frame, this line specifies the specific sheet of the excel document and removing unwanted header where the data resides in the xlsx doc

# %%
data1
# Out:
#     PID Filename               Case  \
# 0    96   96.m4a         Post Strep
# 1    93   93.m4a     Rhabdomyolysis
# 2    90   90.m4a  Urothelial cancer
# 3    76   76.m4a  Urothelial cancer
# 4    63   63.m4a     Rhabdomyolysis
# 5    30   30.mp4  Urothelial cancer
# 6    15   15.m4a     Rhabdomyolysis
# 7    11   11.m4a     Rhabdomyolysis
# 8     5    5.m4a     Rhabdomyolysis
# 9    99   99.m4a         Post Strep
# 10   84   84.m4a     Rhabdomyolysis
# 11   77   77.m4a    Nephrolithiasis
# 12   70   70.m4a  Urothelial cancer
# 13   57   57.m4a    Nephrolithiasis
# 14   55   55.m4a         Post Strep
# 15   53   53.mp4         Post Strep
# 16   37   37.m4a    Nephrolithiasis
#
#                                             Responses
# 0   This is student doctor presenting my patient. ...
# 1   64-year-old female presents to the emergency d...
# 2   Hi there. My name is student doctor and today ...
# 3   Hello, I am presenting today on patient Alex S...
# 4   Hello Dr. Rawlins, I just came from room 8 whe...
# 5   Hello. This is a case presentation of Alex Sab...
# 6   Hi Dr. Rollins, I'd like to present to you Mrs...
# 7   Good afternoon. Our patient today is Alex Savi...
# 8   This is student Dr. reporting on Alex Sabin. M...
# 9   Okay, so I met with a Mr. Alex, 66-year-old ma...
# 10  Hey Dr. Smith, I just got finished seeing Alex...
# 11  Mrs. Alex Sabin is a 67 year old English profe...
# 12  Good afternoon, Dr. Rollins. I had the pleasur...
# 13  Mrs. Alex Sabin is a 67-year-old female who pr...
# 14  Mrs. Sabin is a 66 year old retired professor ...
# 15  Patient is a retired 66 year old man who prese...
# 16  Mr. Alex Sabin is a 67 year old male with the ...

# %%
def remove_punctuations(text): #function to remove punctuation and replace with blank space
    for punctuation in string.punctuation:
        text = text.replace('-',' ')
        text = text.replace(punctuation, '')
        text = text.lstrip()
    return text

# %%
from spellchecker import SpellChecker
spell =SpellChecker()
spell.word_frequency.load_text('Medical Dict.txt')

# %%
def spellcheck(responses):
    unknown =[]
    for i in responses:
        i=i.lower()
        j=remove_punctuations(i)
        text = j.split(' ')
        for word in text:
            if (len(word) <= 2) :
                pass 
            elif (spell.candidates(word) == None):
                unknown.append(word)
                pass
            else:
                print('Potential Spelling Error:')
                print(word)
                print('Replacements')
                print(spell.candidates(word))
    return(unknown)

# %%
data1.iloc[[0,1],3]
# Out:
# 0    This is student doctor presenting my patient. ...
# 1    64-year-old female presents to the emergency d...
# Name: Responses, dtype: object

# %%
unkn=spellcheck(data1.iloc[:,3])
# Out:
# Potential Spelling Error:
# this
# Replacements
# {'this'}
# Potential Spelling Error:
# student
# Replacements
# {'student'}
# Potential Spelling Error:
# doctor
# Replacements
# {'doctor'}
# Potential Spelling Error:
# presenting
# Replacements
# {'presenting'}
# Potential Spelling Error:
# patient
# Replacements
# {'patient'}
# Potential Spelling Error:
# mrs
# Replacements
# {'mors', 'mus', 'yrs', 'ars', 'ers', 'mars', 'mos', 'mras', 'mes', 'irs', 'mas', 'mri', 'mers', 'mis'}
# Potential Spelling Error:
# sabin
# Replacements
# {'cabin', 'satin', 'sarin', 'sabine', 'sabian', 'sayin'}
# Potential Spelling Error:
# year
# Replacements
# {'year'}
# Potential Spelling Error:
# old
# Replacements
# {'old'}
# Potential Spelling Error:
# white
# Replacements
# {'white'}
# Potential Spelling Error:
# female
# Replacements
# {'female'}
# Potential Spelling Error:
# who
# Replacements
# {'who'}
# Potential Spelling Error:
# presents
# Replacements
# {'presents'}
# Potential Spelling Error:
# today
# Replacements
# {'today'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# chief
# Replacements
# {'chief'}
# Potential Spelling Error:
# complaint
# Replacements
# {'complaint'}
# Potential Spelling Error:
# blood
# Replacements
# {'blood'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# urine
# Replacements
# {'urine'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# states
# Replacements
# {'states'}
# Potential Spelling Error:
# that
# Replacements
# {'that'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# urine
# Replacements
# {'urine'}
# Potential Spelling Error:
# has
# Replacements
# {'has'}
# Potential Spelling Error:
# been
# Replacements
# {'been'}
# Potential Spelling Error:
# dark
# Replacements
# {'dark'}
# Potential Spelling Error:
# red
# Replacements
# {'red'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# notes
# Replacements
# {'notes'}
# Potential Spelling Error:
# that
# Replacements
# {'that'}
# Potential Spelling Error:
# started
# Replacements
# {'started'}
# Potential Spelling Error:
# about
# Replacements
# {'about'}
# Potential Spelling Error:
# week
# Replacements
# {'week'}
# Potential Spelling Error:
# ago
# Replacements
# {'ago'}
# Potential Spelling Error:
# note
# Replacements
# {'note'}
# Potential Spelling Error:
# two
# Replacements
# {'two'}
# Potential Spelling Error:
# weeks
# Replacements
# {'weeks'}
# Potential Spelling Error:
# ago
# Replacements
# {'ago'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# states
# Replacements
# {'states'}
# Potential Spelling Error:
# that
# Replacements
# {'that'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# had
# Replacements
# {'had'}
# Potential Spelling Error:
# sore
# Replacements
# {'sore'}
# Potential Spelling Error:
# throat
# Replacements
# {'throat'}
# Potential Spelling Error:
# which
# Replacements
# {'which'}
# Potential Spelling Error:
# not
# Replacements
# {'not'}
# Potential Spelling Error:
# completely
# Replacements
# {'completely'}
# Potential Spelling Error:
# resolved
# Replacements
# {'resolved'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# reports
# Replacements
# {'reports'}
# Potential Spelling Error:
# having
# Replacements
# {'having'}
# Potential Spelling Error:
# sore
# Replacements
# {'sore'}
# Potential Spelling Error:
# throat
# Replacements
# {'throat'}
# Potential Spelling Error:
# difficulty
# Replacements
# {'difficulty'}
# Potential Spelling Error:
# swallowing
# Replacements
# {'swallowing'}
# Potential Spelling Error:
# fever
# Replacements
# {'fever'}
# Potential Spelling Error:
# cough
# Replacements
# {'cough'}
# Potential Spelling Error:
# wheezing
# Replacements
# {'wheezing'}
# Potential Spelling Error:
# increased
# Replacements
# {'increased'}
# Potential Spelling Error:
# lower
# Replacements
# {'lower'}
# Potential Spelling Error:
# extremity
# Replacements
# {'extremity'}
# Potential Spelling Error:
# edema
# Replacements
# {'edema'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# shortness
# Replacements
# {'shortness'}
# Potential Spelling Error:
# breath
# Replacements
# {'breath'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# states
# Replacements
# {'states'}
# Potential Spelling Error:
# that
# Replacements
# {'that'}
# Potential Spelling Error:
# drinking
# Replacements
# {'drinking'}
# Potential Spelling Error:
# cool
# Replacements
# {'cool'}
# Potential Spelling Error:
# water
# Replacements
# {'water'}
# Potential Spelling Error:
# transiently
# Replacements
# {'transient', 'transients'}
# Potential Spelling Error:
# improves
# Replacements
# {'improves'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# symptoms
# Replacements
# {'symptoms'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# that
# Replacements
# {'that'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# also
# Replacements
# {'also'}
# Potential Spelling Error:
# drink
# Replacements
# {'drink'}
# Potential Spelling Error:
# glass
# Replacements
# {'glass'}
# Potential Spelling Error:
# whiskey
# Replacements
# {'whiskey'}
# Potential Spelling Error:
# yesterday
# Replacements
# {'yesterday'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# some
# Replacements
# {'some'}
# Potential Spelling Error:
# relief
# Replacements
# {'relief'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# symptoms
# Replacements
# {'symptoms'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# reports
# Replacements
# {'reports'}
# Potential Spelling Error:
# that
# Replacements
# {'that'}
# Potential Spelling Error:
# eating
# Replacements
# {'eating'}
# Potential Spelling Error:
# makes
# Replacements
# {'makes'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# symptoms
# Replacements
# {'symptoms'}
# Potential Spelling Error:
# worse
# Replacements
# {'worse'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# date
# Replacements
# {'date'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# vaccinations
# Replacements
# {'vaccinations'}
# Potential Spelling Error:
# has
# Replacements
# {'has'}
# Potential Spelling Error:
# insurance
# Replacements
# {'insurance'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# lives
# Replacements
# {'lives'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# husband
# Replacements
# {'husband'}
# Potential Spelling Error:
# who
# Replacements
# {'who'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# social
# Replacements
# {'social'}
# Potential Spelling Error:
# support
# Replacements
# {'support'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# surgical
# Replacements
# {'surgical'}
# Potential Spelling Error:
# history
# Replacements
# {'history'}
# Potential Spelling Error:
# significant
# Replacements
# {'significant'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# splenectomy
# Replacements
# {'splenectomy'}
# Potential Spelling Error:
# following
# Replacements
# {'following'}
# Potential Spelling Error:
# motor
# Replacements
# {'motor'}
# Potential Spelling Error:
# vehicle
# Replacements
# {'vehicle'}
# Potential Spelling Error:
# accident
# Replacements
# {'accident'}
# Potential Spelling Error:
# years
# Replacements
# {'years'}
# Potential Spelling Error:
# old
# Replacements
# {'old'}
# Potential Spelling Error:
# normal
# Replacements
# {'normal'}
# Potential Spelling Error:
# colonoscopy
# Replacements
# {'colonoscopy'}
# Potential Spelling Error:
# years
# Replacements
# {'years'}
# Potential Spelling Error:
# old
# Replacements
# {'old'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# cardiac
# Replacements
# {'cardiac'}
# Potential Spelling Error:
# stent
# Replacements
# {'stent'}
# Potential Spelling Error:
# placement
# Replacements
# {'placement'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# left
# Replacements
# {'left'}
# Potential Spelling Error:
# side
# Replacements
# {'side'}
# Potential Spelling Error:
# age
# Replacements
# {'age'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# which
# Replacements
# {'which'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# takes
# Replacements
# {'takes'}
# Potential Spelling Error:
# mouth
# Replacements
# {'mouth'}
# Potential Spelling Error:
# per
# Replacements
# {'per'}
# Potential Spelling Error:
# day
# Replacements
# {'day'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# medical
# Replacements
# {'medical'}
# Potential Spelling Error:
# history
# Replacements
# {'history'}
# Potential Spelling Error:
# positive
# Replacements
# {'positive'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# hypertension
# Replacements
# {'hypertension'}
# Potential Spelling Error:
# which
# Replacements
# {'which'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# takes
# Replacements
# {'takes'}
# Potential Spelling Error:
# mouth
# Replacements
# {'mouth'}
# Potential Spelling Error:
# every
# Replacements
# {'every'}
# Potential Spelling Error:
# day
# Replacements
# {'day'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# was
# Replacements
# {'was'}
# Potential Spelling Error:
# hospitalized
# Replacements
# {'hospitalized'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# motor
# Replacements
# {'motor'}
# Potential Spelling Error:
# vehicle
# Replacements
# {'vehicle'}
# Potential Spelling Error:
# accident
# Replacements
# {'accident'}
# Potential Spelling Error:
# colonoscopy
# Replacements
# {'colonoscopy'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# stent
# Replacements
# {'stent'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# has
# Replacements
# {'has'}
# Potential Spelling Error:
# known
# Replacements
# {'known'}
# Potential Spelling Error:
# drug
# Replacements
# {'drug'}
# Potential Spelling Error:
# allergies
# Replacements
# {'allergies'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# maternal
# Replacements
# {'maternal'}
# Potential Spelling Error:
# history
# Replacements
# {'history'}
# Potential Spelling Error:
# non
# Replacements
# {'non'}
# Potential Spelling Error:
# contributory
# Replacements
# {'contributory'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# mother
# Replacements
# {'mother'}
# Potential Spelling Error:
# alive
# Replacements
# {'alive'}
# Potential Spelling Error:
# years
# Replacements
# {'years'}
# Potential Spelling Error:
# old
# Replacements
# {'old'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# paternal
# Replacements
# {'paternal'}
# Potential Spelling Error:
# family
# Replacements
# {'family'}
# Potential Spelling Error:
# history
# Replacements
# {'history'}
# Potential Spelling Error:
# positive
# Replacements
# {'positive'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# hypertension
# Replacements
# {'hypertension'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# death
# Replacements
# {'death'}
# Potential Spelling Error:
# age
# Replacements
# {'age'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# notes
# Replacements
# {'notes'}
# Potential Spelling Error:
# that
# Replacements
# {'that'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# eats
# Replacements
# {'eats'}
# Potential Spelling Error:
# balanced
# Replacements
# {'balanced'}
# Potential Spelling Error:
# diet
# Replacements
# {'diet'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# that
# Replacements
# {'that'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# works
# Replacements
# {'works'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# family
# Replacements
# {'family'}
# Potential Spelling Error:
# farm
# Replacements
# {'farm'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# exercise
# Replacements
# {'exercise'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# denies
# Replacements
# {'denies'}
# Potential Spelling Error:
# taking
# Replacements
# {'taking'}
# Potential Spelling Error:
# any
# Replacements
# {'any'}
# Potential Spelling Error:
# illicit
# Replacements
# {'illicit'}
# Potential Spelling Error:
# substances
# Replacements
# {'substances'}
# Potential Spelling Error:
# tobacco
# Replacements
# {'tobacco'}
# Potential Spelling Error:
# use
# Replacements
# {'use'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# denies
# Replacements
# {'denies'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# does
# Replacements
# {'does'}
# Potential Spelling Error:
# report
# Replacements
# {'report'}
# Potential Spelling Error:
# having
# Replacements
# {'having'}
# Potential Spelling Error:
# approximately
# Replacements
# {'approximately'}
# Potential Spelling Error:
# one
# Replacements
# {'one'}
# Potential Spelling Error:
# drink
# Replacements
# {'drink'}
# Potential Spelling Error:
# alcohol
# Replacements
# {'alcohol'}
# Potential Spelling Error:
# per
# Replacements
# {'per'}
# Potential Spelling Error:
# day
# Replacements
# {'day'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# couple
# Replacements
# {'couple'}
# Potential Spelling Error:
# cups
# Replacements
# {'cups'}
# Potential Spelling Error:
# coffee
# Replacements
# {'coffee'}
# Potential Spelling Error:
# per
# Replacements
# {'per'}
# Potential Spelling Error:
# day
# Replacements
# {'day'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# used
# Replacements
# {'used'}
# Potential Spelling Error:
# work
# Replacements
# {'work'}
# Potential Spelling Error:
# history
# Replacements
# {'history'}
# Potential Spelling Error:
# teacher
# Replacements
# {'teacher'}
# Potential Spelling Error:
# but
# Replacements
# {'but'}
# Potential Spelling Error:
# now
# Replacements
# {'now'}
# Potential Spelling Error:
# lives
# Replacements
# {'lives'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# farm
# Replacements
# {'farm'}
# Potential Spelling Error:
# full
# Replacements
# {'full'}
# Potential Spelling Error:
# time
# Replacements
# {'time'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# lives
# Replacements
# {'lives'}
# Potential Spelling Error:
# home
# Replacements
# {'home'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# husband
# Replacements
# {'husband'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# review
# Replacements
# {'review'}
# Potential Spelling Error:
# systems
# Replacements
# {'systems'}
# Potential Spelling Error:
# reveals
# Replacements
# {'reveals'}
# Potential Spelling Error:
# fever
# Replacements
# {'fever'}
# Potential Spelling Error:
# recent
# Replacements
# {'recent'}
# Potential Spelling Error:
# weight
# Replacements
# {'weight'}
# Potential Spelling Error:
# gain
# Replacements
# {'gain'}
# Potential Spelling Error:
# pounds
# Replacements
# {'pounds'}
# Potential Spelling Error:
# sore
# Replacements
# {'sore'}
# Potential Spelling Error:
# throat
# Replacements
# {'throat'}
# Potential Spelling Error:
# shortness
# Replacements
# {'shortness'}
# Potential Spelling Error:
# breath
# Replacements
# {'breath'}
# Potential Spelling Error:
# non
# Replacements
# {'non'}
# Potential Spelling Error:
# productive
# Replacements
# {'productive'}
# Potential Spelling Error:
# cough
# Replacements
# {'cough'}
# Potential Spelling Error:
# dark
# Replacements
# {'dark'}
# Potential Spelling Error:
# red
# Replacements
# {'red'}
# Potential Spelling Error:
# brown
# Replacements
# {'brown'}
# Potential Spelling Error:
# urine
# Replacements
# {'urine'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# lower
# Replacements
# {'lower'}
# Potential Spelling Error:
# extremity
# Replacements
# {'extremity'}
# Potential Spelling Error:
# edema
# Replacements
# {'edema'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# rest
# Replacements
# {'rest'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# ros
# Replacements
# {'dos', 'rosy', 'roi', 'yos', 'rou', 'rods', 'ron', 'rop', 'roes', 'roc', 'roe', 'ross', 'hos', 'rose', 'res', 'rios', 'rot', 'pros', 'eros', 'rob', 'nos', 'gos', 'rots', 'bros', 'roy', 'los', 'rosa', 'rod', 'rog', 'roz', 'row', 'sos', 'vos', 'os', 'robs', 'cos', 'roo', 'ro', 'ror', 'rows', 'ras', 'mos', 'rom', 'pos', 'ryos'}
# Potential Spelling Error:
# non
# Replacements
# {'non'}
# Potential Spelling Error:
# contributory
# Replacements
# {'contributory'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# vitals
# Replacements
# {'vitals'}
# Potential Spelling Error:
# are
# Replacements
# {'are'}
# Potential Spelling Error:
# positive
# Replacements
# {'positive'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# fever
# Replacements
# {'fever'}
# Potential Spelling Error:
# 1015
# Replacements
# {'1015'}
# Potential Spelling Error:
# degrees
# Replacements
# {'degrees'}
# Potential Spelling Error:
# fahrenheit
# Replacements
# {'fahrenheit'}
# Potential Spelling Error:
# elevated
# Replacements
# {'elevated'}
# Potential Spelling Error:
# respirations
# Replacements
# {'respirations'}
# Potential Spelling Error:
# beats
# Replacements
# {'beats'}
# Potential Spelling Error:
# per
# Replacements
# {'per'}
# Potential Spelling Error:
# minute
# Replacements
# {'minute'}
# Potential Spelling Error:
# elevated
# Replacements
# {'elevated'}
# Potential Spelling Error:
# blood
# Replacements
# {'blood'}
# Potential Spelling Error:
# pressure
# Replacements
# {'pressure'}
# Potential Spelling Error:
# 185
# Replacements
# {'185'}
# Potential Spelling Error:
# over
# Replacements
# {'over'}
# Potential Spelling Error:
# 105
# Replacements
# {'105'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# sat
# Replacements
# {'sat'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# rest
# Replacements
# {'rest'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# vital
# Replacements
# {'vital'}
# Potential Spelling Error:
# signs
# Replacements
# {'signs'}
# Potential Spelling Error:
# are
# Replacements
# {'are'}
# Potential Spelling Error:
# within
# Replacements
# {'within'}
# Potential Spelling Error:
# normal
# Replacements
# {'normal'}
# Potential Spelling Error:
# limits
# Replacements
# {'limits'}
# Potential Spelling Error:
# physical
# Replacements
# {'physical'}
# Potential Spelling Error:
# exam
# Replacements
# {'exam'}
# Potential Spelling Error:
# mrs
# Replacements
# {'mors', 'mus', 'yrs', 'ars', 'ers', 'mars', 'mos', 'mras', 'mes', 'irs', 'mas', 'mri', 'mers', 'mis'}
# Potential Spelling Error:
# sabin
# Replacements
# {'cabin', 'satin', 'sarin', 'sabine', 'sabian', 'sayin'}
# Potential Spelling Error:
# slightly
# Replacements
# {'slightly'}
# Potential Spelling Error:
# overweight
# Replacements
# {'overweight'}
# Potential Spelling Error:
# woman
# Replacements
# {'woman'}
# Potential Spelling Error:
# who
# Replacements
# {'who'}
# Potential Spelling Error:
# appears
# Replacements
# {'appears'}
# Potential Spelling Error:
# alert
# Replacements
# {'alert'}
# Potential Spelling Error:
# oriented
# Replacements
# {'oriented'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# wake
# Replacements
# {'wake'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# oral
# Replacements
# {'oral'}
# Potential Spelling Error:
# mucosa
# Replacements
# {'mucosa'}
# Potential Spelling Error:
# reveals
# Replacements
# {'reveals'}
# Potential Spelling Error:
# exudate
# Replacements
# {'caudate', 'erudite', 'educate', 'expiate', 'equate', 'exude', 'emulate', 'extubate'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# pharyngeal
# Replacements
# {'laryngeal'}
# Potential Spelling Error:
# erythema
# Replacements
# {'erythema'}
# Potential Spelling Error:
# palpation
# Replacements
# {'valuation', 'palpitation', 'salvation', 'palpatine'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# neck
# Replacements
# {'neck'}
# Potential Spelling Error:
# was
# Replacements
# {'was'}
# Potential Spelling Error:
# negative
# Replacements
# {'negative'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# cervical
# Replacements
# {'cervical'}
# Potential Spelling Error:
# goiter
# Replacements
# {'goiter'}
# Potential Spelling Error:
# tenderness
# Replacements
# {'tenderness'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# cardiac
# Replacements
# {'cardiac'}
# Potential Spelling Error:
# examination
# Replacements
# {'examination'}
# Potential Spelling Error:
# reveals
# Replacements
# {'reveals'}
# Potential Spelling Error:
# normal
# Replacements
# {'normal'}
# Potential Spelling Error:
# rate
# Replacements
# {'rate'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# rhythm
# Replacements
# {'rhythm'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# murmurs
# Replacements
# {'murmurs'}
# Potential Spelling Error:
# rubs
# Replacements
# {'rubs'}
# Potential Spelling Error:
# gallops
# Replacements
# {'gallops'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# peripheral
# Replacements
# {'peripheral'}
# Potential Spelling Error:
# pulses
# Replacements
# {'pulses'}
# Potential Spelling Error:
# are
# Replacements
# {'are'}
# Potential Spelling Error:
# plus
# Replacements
# {'plus'}
# Potential Spelling Error:
# bilaterally
# Replacements
# {'bilaterally'}
# Potential Spelling Error:
# however
# Replacements
# {'however'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# lower
# Replacements
# {'lower'}
# Potential Spelling Error:
# extremities
# Replacements
# {'extremities'}
# Potential Spelling Error:
# are
# Replacements
# {'are'}
# Potential Spelling Error:
# positive
# Replacements
# {'positive'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# plus
# Replacements
# {'plus'}
# Potential Spelling Error:
# bilateral
# Replacements
# {'bilateral'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# symmetric
# Replacements
# {'symmetric'}
# Potential Spelling Error:
# pitting
# Replacements
# {'pitting'}
# Potential Spelling Error:
# edema
# Replacements
# {'edema'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# pulmonary
# Replacements
# {'pulmonary'}
# Potential Spelling Error:
# examination
# Replacements
# {'examination'}
# Potential Spelling Error:
# reveals
# Replacements
# {'reveals'}
# Potential Spelling Error:
# non
# Replacements
# {'non'}
# Potential Spelling Error:
# labored
# Replacements
# {'labored'}
# Potential Spelling Error:
# breathing
# Replacements
# {'breathing'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# lungs
# Replacements
# {'lungs'}
# Potential Spelling Error:
# that
# Replacements
# {'that'}
# Potential Spelling Error:
# are
# Replacements
# {'are'}
# Potential Spelling Error:
# clear
# Replacements
# {'clear'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# wheezing
# Replacements
# {'wheezing'}
# Potential Spelling Error:
# crackles
# Replacements
# {'crackles'}
# Potential Spelling Error:
# rhonchi
# Replacements
# {'honcho', 'bronchi'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# abdomen
# Replacements
# {'abdomen'}
# Potential Spelling Error:
# non
# Replacements
# {'non'}
# Potential Spelling Error:
# distended
# Replacements
# {'distended'}
# Potential Spelling Error:
# without
# Replacements
# {'without'}
# Potential Spelling Error:
# rigidity
# Replacements
# {'rigidity'}
# Potential Spelling Error:
# guarding
# Replacements
# {'guarding'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# bowel
# Replacements
# {'bowel'}
# Potential Spelling Error:
# sounds
# Replacements
# {'sounds'}
# Potential Spelling Error:
# are
# Replacements
# {'are'}
# Potential Spelling Error:
# present
# Replacements
# {'present'}
# Potential Spelling Error:
# there
# Replacements
# {'there'}
# Potential Spelling Error:
# are
# Replacements
# {'are'}
# Potential Spelling Error:
# masses
# Replacements
# {'masses'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# osteopathic
# Replacements
# {'osteopath'}
# Potential Spelling Error:
# screening
# Replacements
# {'screening'}
# Potential Spelling Error:
# reveals
# Replacements
# {'reveals'}
# Potential Spelling Error:
# tart
# Replacements
# {'tart'}
# Potential Spelling Error:
# changes
# Replacements
# {'changes'}
# Potential Spelling Error:
# tenderness
# Replacements
# {'tenderness'}
# Potential Spelling Error:
# reviewed
# Replacements
# {'reviewed'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# exam
# Replacements
# {'exam'}
# Potential Spelling Error:
# findings
# Replacements
# {'findings'}
# Potential Spelling Error:
# lab
# Replacements
# {'lab'}
# Potential Spelling Error:
# values
# Replacements
# {'values'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# imaging
# Replacements
# {'imaging'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# patient
# Replacements
# {'patient'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# bun
# Replacements
# {'bun'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# creatinine
# Replacements
# {'creatinine'}
# Potential Spelling Error:
# ratio
# Replacements
# {'ratio'}
# Potential Spelling Error:
# was
# Replacements
# {'was'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# esr
# Replacements
# {'ese', 'ers', 'est', 'esa', 'ser', 'err', 'eer', 'esp', 'er', 'eso', 'ear', 'ess', 'esu', 'es'}
# Potential Spelling Error:
# was
# Replacements
# {'was'}
# Potential Spelling Error:
# indicative
# Replacements
# {'indicative'}
# Potential Spelling Error:
# inflammation
# Replacements
# {'inflammation'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# cbc
# Replacements
# {'abc', 'cbi'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# bmp
# Replacements
# {'amp', 'bup', 'bap', 'ump', 'emp', 'bop', 'imp', 'bump', 'bip'}
# Potential Spelling Error:
# were
# Replacements
# {'were'}
# Potential Spelling Error:
# within
# Replacements
# {'within'}
# Potential Spelling Error:
# normal
# Replacements
# {'normal'}
# Potential Spelling Error:
# limits
# Replacements
# {'limits'}
# Potential Spelling Error:
# troponin
# Replacements
# {'troponin'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# bnp
# Replacements
# {'bip', 'bop', 'bup', 'bap'}
# Potential Spelling Error:
# were
# Replacements
# {'were'}
# Potential Spelling Error:
# elevated
# Replacements
# {'elevated'}
# Potential Spelling Error:
# addition
# Replacements
# {'addition'}
# Potential Spelling Error:
# positive
# Replacements
# {'positive'}
# Potential Spelling Error:
# tests
# Replacements
# {'tests'}
# Potential Spelling Error:
# indicating
# Replacements
# {'indicating'}
# Potential Spelling Error:
# infection
# Replacements
# {'infection'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# group
# Replacements
# {'group'}
# Potential Spelling Error:
# streptococcus
# Replacements
# {'streptococcus'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# urine
# Replacements
# {'urine'}
# Potential Spelling Error:
# analysis
# Replacements
# {'analysis'}
# Potential Spelling Error:
# revealed
# Replacements
# {'revealed'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# red
# Replacements
# {'red'}
# Potential Spelling Error:
# blood
# Replacements
# {'blood'}
# Potential Spelling Error:
# cells
# Replacements
# {'cells'}
# Potential Spelling Error:
# white
# Replacements
# {'white'}
# Potential Spelling Error:
# blood
# Replacements
# {'blood'}
# Potential Spelling Error:
# cells
# Replacements
# {'cells'}
# Potential Spelling Error:
# plus
# Replacements
# {'plus'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# chest
# Replacements
# {'chest'}
# Potential Spelling Error:
# ray
# Replacements
# {'ray'}
# Potential Spelling Error:
# reveals
# Replacements
# {'reveals'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# pulmonary
# Replacements
# {'pulmonary'}
# Potential Spelling Error:
# edema
# Replacements
# {'edema'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# ekg
# Replacements
# {'ekg'}
# Potential Spelling Error:
# reveals
# Replacements
# {'reveals'}
# Potential Spelling Error:
# normal
# Replacements
# {'normal'}
# Potential Spelling Error:
# axis
# Replacements
# {'axis'}
# Potential Spelling Error:
# sinus
# Replacements
# {'sinus'}
# Potential Spelling Error:
# rhythm
# Replacements
# {'rhythm'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# left
# Replacements
# {'left'}
# Potential Spelling Error:
# bundle
# Replacements
# {'bundle'}
# Potential Spelling Error:
# branch
# Replacements
# {'branch'}
# Potential Spelling Error:
# block
# Replacements
# {'block'}
# Potential Spelling Error:
# due
# Replacements
# {'due'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# history
# Replacements
# {'history'}
# Potential Spelling Error:
# sore
# Replacements
# {'sore'}
# Potential Spelling Error:
# throat
# Replacements
# {'throat'}
# Potential Spelling Error:
# cough
# Replacements
# {'cough'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# diagnosed
# Replacements
# {'diagnosed'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# patient
# Replacements
# {'patient'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# post
# Replacements
# {'post'}
# Potential Spelling Error:
# strep
# Replacements
# {'strep'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# admitted
# Replacements
# {'admitted'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# telemetry
# Replacements
# {'telemetry'}
# Potential Spelling Error:
# serious
# Replacements
# {'serious'}
# Potential Spelling Error:
# condition
# Replacements
# {'condition'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# consulted
# Replacements
# {'consulted'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# hospitalist
# Replacements
# {'hospitalise'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# nephrologist
# Replacements
# {'neurologist'}
# Potential Spelling Error:
# differential
# Replacements
# {'differential'}
# Potential Spelling Error:
# diagnosis
# Replacements
# {'diagnosis'}
# Potential Spelling Error:
# includes
# Replacements
# {'includes'}
# Potential Spelling Error:
# pulmonary
# Replacements
# {'pulmonary'}
# Potential Spelling Error:
# edema
# Replacements
# {'edema'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# acute
# Replacements
# {'acute'}
# Potential Spelling Error:
# kidney
# Replacements
# {'kidney'}
# Potential Spelling Error:
# injury
# Replacements
# {'injury'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# vitals
# Replacements
# {'vitals'}
# Potential Spelling Error:
# are
# Replacements
# {'are'}
# Potential Spelling Error:
# monitored
# Replacements
# {'monitored'}
# Potential Spelling Error:
# every
# Replacements
# {'every'}
# Potential Spelling Error:
# four
# Replacements
# {'four'}
# Potential Spelling Error:
# hours
# Replacements
# {'hours'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# shes
# Replacements
# {'shes'}
# Potential Spelling Error:
# allowed
# Replacements
# {'allowed'}
# Potential Spelling Error:
# get
# Replacements
# {'get'}
# Potential Spelling Error:
# out
# Replacements
# {'out'}
# Potential Spelling Error:
# bed
# Replacements
# {'bed'}
# Potential Spelling Error:
# tolerated
# Replacements
# {'tolerated'}
# Potential Spelling Error:
# nursing
# Replacements
# {'nursing'}
# Potential Spelling Error:
# will
# Replacements
# {'will'}
# Potential Spelling Error:
# deliver
# Replacements
# {'deliver'}
# Potential Spelling Error:
# nasal
# Replacements
# {'nasal'}
# Potential Spelling Error:
# cannula
# Replacements
# {'cannula'}
# Potential Spelling Error:
# increase
# Replacements
# {'increase'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# o2sats
# Replacements
# {'oats', 'sats'}
# Potential Spelling Error:
# above
# Replacements
# {'above'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# provide
# Replacements
# {'provide'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# dvt
# Replacements
# {'det', 'dat', 'dit', 'dut', 'dot'}
# Potential Spelling Error:
# prophylaxis
# Replacements
# {'prophylaxis'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# incentive
# Replacements
# {'incentive'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# will
# Replacements
# {'will'}
# Potential Spelling Error:
# placed
# Replacements
# {'placed'}
# Potential Spelling Error:
# low
# Replacements
# {'low'}
# Potential Spelling Error:
# potassium
# Replacements
# {'potassium'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# phosphorous
# Replacements
# {'phosphorous'}
# Potential Spelling Error:
# diet
# Replacements
# {'diet'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# will
# Replacements
# {'will'}
# Potential Spelling Error:
# kvo
# Replacements
# {'kno', 'ivo', 'evo', 'koo', 'keo', 'vo', 'kao', 'ovo', 'ko'}
# Potential Spelling Error:
# will
# Replacements
# {'will'}
# Potential Spelling Error:
# discontinue
# Replacements
# {'discontinue'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# but
# Replacements
# {'but'}
# Potential Spelling Error:
# well
# Replacements
# {'well'}
# Potential Spelling Error:
# continue
# Replacements
# {'continue'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# start
# Replacements
# {'start'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# amoxicillin
# Replacements
# {'amoxicillin'}
# Potential Spelling Error:
# acetaminophen
# Replacements
# {'acetaminophen'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# fever
# Replacements
# {'fever'}
# Potential Spelling Error:
# lasix
# Replacements
# {'lasik'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# edema
# Replacements
# {'edema'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# blood
# Replacements
# {'blood'}
# Potential Spelling Error:
# pressure
# Replacements
# {'pressure'}
# Potential Spelling Error:
# will
# Replacements
# {'will'}
# Potential Spelling Error:
# order
# Replacements
# {'order'}
# Potential Spelling Error:
# daily
# Replacements
# {'daily'}
# Potential Spelling Error:
# urine
# Replacements
# {'urine'}
# Potential Spelling Error:
# analysis
# Replacements
# {'analysis'}
# Potential Spelling Error:
# esr
# Replacements
# {'ese', 'ers', 'est', 'esa', 'ser', 'err', 'eer', 'esp', 'er', 'eso', 'ear', 'ess', 'esu', 'es'}
# Potential Spelling Error:
# bmp
# Replacements
# {'amp', 'bup', 'bap', 'ump', 'emp', 'bop', 'imp', 'bump', 'bip'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# then
# Replacements
# {'then'}
# Potential Spelling Error:
# will
# Replacements
# {'will'}
# Potential Spelling Error:
# also
# Replacements
# {'also'}
# Potential Spelling Error:
# get
# Replacements
# {'get'}
# Potential Spelling Error:
# additional
# Replacements
# {'additional'}
# Potential Spelling Error:
# chest
# Replacements
# {'chest'}
# Potential Spelling Error:
# rays
# Replacements
# {'rays'}
# Potential Spelling Error:
# during
# Replacements
# {'during'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# treatment
# Replacements
# {'treatment'}
# Potential Spelling Error:
# track
# Replacements
# {'track'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# course
# Replacements
# {'course'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# progression
# Replacements
# {'progression'}
# Potential Spelling Error:
# answered
# Replacements
# {'answered'}
# Potential Spelling Error:
# all
# Replacements
# {'all'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# patients
# Replacements
# {'patients'}
# Potential Spelling Error:
# questions
# Replacements
# {'questions'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# understands
# Replacements
# {'understands'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# agreement
# Replacements
# {'agreement'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# treatment
# Replacements
# {'treatment'}
# Potential Spelling Error:
# plan
# Replacements
# {'plan'}
# Potential Spelling Error:
# year
# Replacements
# {'year'}
# Potential Spelling Error:
# old
# Replacements
# {'old'}
# Potential Spelling Error:
# female
# Replacements
# {'female'}
# Potential Spelling Error:
# presents
# Replacements
# {'presents'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# emergency
# Replacements
# {'emergency'}
# Potential Spelling Error:
# department
# Replacements
# {'department'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# one
# Replacements
# {'one'}
# Potential Spelling Error:
# day
# Replacements
# {'day'}
# Potential Spelling Error:
# onset
# Replacements
# {'onset'}
# Potential Spelling Error:
# blood
# Replacements
# {'blood'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# urine
# Replacements
# {'urine'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# patient
# Replacements
# {'patient'}
# Potential Spelling Error:
# has
# Replacements
# {'has'}
# Potential Spelling Error:
# started
# Replacements
# {'started'}
# Potential Spelling Error:
# condition
# Replacements
# {'condition'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# half
# Replacements
# {'half'}
# Potential Spelling Error:
# marathon
# Replacements
# {'marathon'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# admits
# Replacements
# {'admits'}
# Potential Spelling Error:
# consuming
# Replacements
# {'consuming'}
# Potential Spelling Error:
# two
# Replacements
# {'two'}
# Potential Spelling Error:
# alcoholic
# Replacements
# {'alcoholic'}
# Potential Spelling Error:
# beverages
# Replacements
# {'beverages'}
# Potential Spelling Error:
# two
# Replacements
# {'two'}
# Potential Spelling Error:
# days
# Replacements
# {'days'}
# Potential Spelling Error:
# ago
# Replacements
# {'ago'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# inadequately
# Replacements
# {'inadequately'}
# Potential Spelling Error:
# hydrating
# Replacements
# {'hydrating'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# water
# Replacements
# {'water'}
# Potential Spelling Error:
# yesterday
# Replacements
# {'yesterday'}
# Potential Spelling Error:
# while
# Replacements
# {'while'}
# Potential Spelling Error:
# running
# Replacements
# {'running'}
# Potential Spelling Error:
# when
# Replacements
# {'when'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# ran
# Replacements
# {'ran'}
# Potential Spelling Error:
# miles
# Replacements
# {'miles'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# urine
# Replacements
# {'urine'}
# Potential Spelling Error:
# was
# Replacements
# {'was'}
# Potential Spelling Error:
# dark
# Replacements
# {'dark'}
# Potential Spelling Error:
# this
# Replacements
# {'this'}
# Potential Spelling Error:
# morning
# Replacements
# {'morning'}
# Potential Spelling Error:
# prompting
# Replacements
# {'prompting'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# come
# Replacements
# {'come'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# urine
# Replacements
# {'urine'}
# Potential Spelling Error:
# output
# Replacements
# {'output'}
# Potential Spelling Error:
# has
# Replacements
# {'has'}
# Potential Spelling Error:
# decreased
# Replacements
# {'decreased'}
# Potential Spelling Error:
# throughout
# Replacements
# {'throughout'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# day
# Replacements
# {'day'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# admits
# Replacements
# {'admits'}
# Potential Spelling Error:
# fatigue
# Replacements
# {'fatigue'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# reports
# Replacements
# {'reports'}
# Potential Spelling Error:
# muscle
# Replacements
# {'muscle'}
# Potential Spelling Error:
# aches
# Replacements
# {'aches'}
# Potential Spelling Error:
# all
# Replacements
# {'all'}
# Potential Spelling Error:
# over
# Replacements
# {'over'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# body
# Replacements
# {'body'}
# Potential Spelling Error:
# but
# Replacements
# {'but'}
# Potential Spelling Error:
# especially
# Replacements
# {'especially'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# calves
# Replacements
# {'calves'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# thighs
# Replacements
# {'thighs'}
# Potential Spelling Error:
# personal
# Replacements
# {'personal'}
# Potential Spelling Error:
# medical
# Replacements
# {'medical'}
# Potential Spelling Error:
# history
# Replacements
# {'history'}
# Potential Spelling Error:
# includes
# Replacements
# {'includes'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# which
# Replacements
# {'which'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# takes
# Replacements
# {'takes'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# which
# Replacements
# {'which'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# takes
# Replacements
# {'takes'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# states
# Replacements
# {'states'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# has
# Replacements
# {'has'}
# Potential Spelling Error:
# been
# Replacements
# {'been'}
# Potential Spelling Error:
# out
# Replacements
# {'out'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# couple
# Replacements
# {'couple'}
# Potential Spelling Error:
# weeks
# Replacements
# {'weeks'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# need
# Replacements
# {'need'}
# Potential Spelling Error:
# refill
# Replacements
# {'refill'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# has
# Replacements
# {'has'}
# Potential Spelling Error:
# known
# Replacements
# {'known'}
# Potential Spelling Error:
# drug
# Replacements
# {'drug'}
# Potential Spelling Error:
# allergies
# Replacements
# {'allergies'}
# Potential Spelling Error:
# she
# Replacements
# {'she'}
# Potential Spelling Error:
# retired
# Replacements
# {'retired'}
# Potential Spelling Error:
# eats
# Replacements
# {'eats'}
# Potential Spelling Error:
# balanced
# Replacements
# {'balanced'}
# Potential Spelling Error:
# diet
# Replacements
# {'diet'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# exercises
# Replacements
# {'exercises'}
# Potential Spelling Error:
# regularly
# Replacements
# {'regularly'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# drug
# Replacements
# {'drug'}
# Potential Spelling Error:
# tobacco
# Replacements
# {'tobacco'}
# Potential Spelling Error:
# use
# Replacements
# {'use'}
# Potential Spelling Error:
# mother
# Replacements
# {'mother'}
# Potential Spelling Error:
# deceased
# Replacements
# {'deceased'}
# Potential Spelling Error:
# from
# Replacements
# {'from'}
# Potential Spelling Error:
# stroke
# Replacements
# {'stroke'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# father
# Replacements
# {'father'}
# Potential Spelling Error:
# alive
# Replacements
# {'alive'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# physical
# Replacements
# {'physical'}
# Potential Spelling Error:
# exam
# Replacements
# {'exam'}
# Potential Spelling Error:
# confirmed
# Replacements
# {'confirmed'}
# Potential Spelling Error:
# swelling
# Replacements
# {'swelling'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# tenderness
# Replacements
# {'tenderness'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# lower
# Replacements
# {'lower'}
# Potential Spelling Error:
# extremities
# Replacements
# {'extremities'}
# Potential Spelling Error:
# her
# Replacements
# {'her'}
# Potential Spelling Error:
# rate
# Replacements
# {'rate'}
# Potential Spelling Error:
# was
# Replacements
# {'was'}
# Potential Spelling Error:
# tachycardic
# Replacements
# {'tachycardic'}
# Potential Spelling Error:
# 105
# Replacements
# {'105'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# all
# Replacements
# {'all'}
# Potential Spelling Error:
# other
# Replacements
# {'other'}
# Potential Spelling Error:
# vitals
# Replacements
# {'vitals'}
# Potential Spelling Error:
# being
# Replacements
# {'being'}
# Potential Spelling Error:
# normal
# Replacements
# {'normal'}
# Potential Spelling Error:
# ordered
# Replacements
# {'ordered'}
# Potential Spelling Error:
# labs
# Replacements
# {'labs'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# ekg
# Replacements
# {'ekg'}
# Potential Spelling Error:
# patient
# Replacements
# {'patient'}
# Potential Spelling Error:
# has
# Replacements
# {'has'}
# Potential Spelling Error:
# elevated
# Replacements
# {'elevated'}
# Potential Spelling Error:
# bun
# Replacements
# {'bun'}
# Potential Spelling Error:
# creatinine
# Replacements
# {'creatinine'}
# Potential Spelling Error:
# phosphorus
# Replacements
# {'phosphorus'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# rbcs
# Replacements
# {'regs', 'rays', 'rios', 'orbs', 'rico', 'refs', 'rams', 'robs', 'obs', 'rec', 'reck', 'runs', 'docs', 'rows', 'racy', 'revs', 'pacs', 'ric', 'rums', "rib's", 'rubs', 'arcs', 'roc', 'pecs', 'rads', 'mics', 'ricks', 'rots', 'ibis', 'reps', 'raps', 'abs', 'bes', 'rich', 'sacs', 'rugs', 'rice', 'ryos', 'bas', 'reco', 'rubes', 'rods', 'ruts', 'rids', "orb's", 'rocks', 'rick', 'res', 'ruck', 'rock', 'bros', 'abc', 'bus', 'lacs', 'rips', 'rats', 'rags', 'bras', 'tics', 'rims', 'ribs', "rob's", 'reds', 'ross', 'race', 'rebs', 'rhys', 'crocs', 'robes', 'macs', 'races', 'vics', 'roes', 'bis', 'bris', 'tacs', 'secs', 'rhis', 'ebbs', 'russ', 'pics', "ra's", 'racks', 'ras', 'rigs', 'rack', 'orcs'}
# Potential Spelling Error:
# urine
# Replacements
# {'urine'}
# Potential Spelling Error:
# ekg
# Replacements
# {'ekg'}
# Potential Spelling Error:
# showed
# Replacements
# {'showed'}
# Potential Spelling Error:
# sinus
# Replacements
# {'sinus'}
# Potential Spelling Error:
# rhythm
# Replacements
# {'rhythm'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# normal
# Replacements
# {'normal'}
# Potential Spelling Error:
# axis
# Replacements
# {'axis'}
# Potential Spelling Error:
# wide
# Replacements
# {'wide'}
# Potential Spelling Error:
# qrs
# Replacements
# {'ars', 'ers', 'irs', 'yrs'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# peaked
# Replacements
# {'peaked'}
# Potential Spelling Error:
# waves
# Replacements
# {'waves'}
# Potential Spelling Error:
# diagnosed
# Replacements
# {'diagnosed'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# patient
# Replacements
# {'patient'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# acute
# Replacements
# {'acute'}
# Potential Spelling Error:
# kidney
# Replacements
# {'kidney'}
# Potential Spelling Error:
# injury
# Replacements
# {'injury'}
# Potential Spelling Error:
# then
# Replacements
# {'then'}
# Potential Spelling Error:
# admitted
# Replacements
# {'admitted'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# patient
# Replacements
# {'patient'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# icu
# Replacements
# {'icu'}
# Potential Spelling Error:
# serious
# Replacements
# {'serious'}
# Potential Spelling Error:
# condition
# Replacements
# {'condition'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# ordered
# Replacements
# {'ordered'}
# Potential Spelling Error:
# vital
# Replacements
# {'vital'}
# Potential Spelling Error:
# signs
# Replacements
# {'signs'}
# Potential Spelling Error:
# every
# Replacements
# {'every'}
# Potential Spelling Error:
# two
# Replacements
# {'two'}
# Potential Spelling Error:
# hours
# Replacements
# {'hours'}
# Potential Spelling Error:
# activity
# Replacements
# {'activity'}
# Potential Spelling Error:
# tolerated
# Replacements
# {'tolerated'}
# Potential Spelling Error:
# with
# Replacements
# {'with'}
# Potential Spelling Error:
# nursing
# Replacements
# {'nursing'}
# ...
# Potential Spelling Error:
# four
# Replacements
# {'four'}
# Potential Spelling Error:
# five
# Replacements
# {'five'}
# Potential Spelling Error:
# times
# Replacements
# {'times'}
# Potential Spelling Error:
# week
# Replacements
# {'week'}
# Potential Spelling Error:
# currently
# Replacements
# {'currently'}
# Potential Spelling Error:
# employed
# Replacements
# {'employed'}
# Potential Spelling Error:
# college
# Replacements
# {'college'}
# Potential Spelling Error:
# professor
# Replacements
# {'professor'}
# Potential Spelling Error:
# review
# Replacements
# {'review'}
# Potential Spelling Error:
# systems
# Replacements
# {'systems'}
# Potential Spelling Error:
# reveals
# Replacements
# {'reveals'}
# Potential Spelling Error:
# other
# Replacements
# {'other'}
# Potential Spelling Error:
# pertinent
# Replacements
# {'pertinent'}
# Potential Spelling Error:
# positives
# Replacements
# {'positives'}
# Potential Spelling Error:
# negatives
# Replacements
# {'negatives'}
# Potential Spelling Error:
# besides
# Replacements
# {'besides'}
# Potential Spelling Error:
# those
# Replacements
# {'those'}
# Potential Spelling Error:
# presented
# Replacements
# {'presented'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# history
# Replacements
# {'history'}
# Potential Spelling Error:
# present
# Replacements
# {'present'}
# Potential Spelling Error:
# illness
# Replacements
# {'illness'}
# Potential Spelling Error:
# upon
# Replacements
# {'upon'}
# Potential Spelling Error:
# physical
# Replacements
# {'physical'}
# Potential Spelling Error:
# exam
# Replacements
# {'exam'}
# Potential Spelling Error:
# saber
# Replacements
# {'saber'}
# Potential Spelling Error:
# alert
# Replacements
# {'alert'}
# Potential Spelling Error:
# oriented
# Replacements
# {'oriented'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# well
# Replacements
# {'well'}
# Potential Spelling Error:
# groomed
# Replacements
# {'groomed'}
# Potential Spelling Error:
# vitals
# Replacements
# {'vitals'}
# Potential Spelling Error:
# include
# Replacements
# {'include'}
# Potential Spelling Error:
# temperature
# Replacements
# {'temperature'}
# Potential Spelling Error:
# 986
# Replacements
# {'986'}
# Potential Spelling Error:
# degrees
# Replacements
# {'degrees'}
# Potential Spelling Error:
# heart
# Replacements
# {'heart'}
# Potential Spelling Error:
# rate
# Replacements
# {'rate'}
# Potential Spelling Error:
# beats
# Replacements
# {'beats'}
# Potential Spelling Error:
# per
# Replacements
# {'per'}
# Potential Spelling Error:
# minute
# Replacements
# {'minute'}
# Potential Spelling Error:
# respiratory
# Replacements
# {'respiratory'}
# Potential Spelling Error:
# rate
# Replacements
# {'rate'}
# Potential Spelling Error:
# blood
# Replacements
# {'blood'}
# Potential Spelling Error:
# pressure
# Replacements
# {'pressure'}
# Potential Spelling Error:
# was
# Replacements
# {'was'}
# Potential Spelling Error:
# elevated
# Replacements
# {'elevated'}
# Potential Spelling Error:
# 139
# Replacements
# {'139'}
# Potential Spelling Error:
# over
# Replacements
# {'over'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# his
# Replacements
# {'his'}
# Potential Spelling Error:
# oxygen
# Replacements
# {'oxygen'}
# Potential Spelling Error:
# was
# Replacements
# {'was'}
# Potential Spelling Error:
# 100
# Replacements
# {'100'}
# Potential Spelling Error:
# skin
# Replacements
# {'skin'}
# Potential Spelling Error:
# color
# Replacements
# {'color'}
# Potential Spelling Error:
# looks
# Replacements
# {'looks'}
# Potential Spelling Error:
# good
# Replacements
# {'good'}
# Potential Spelling Error:
# atypical
# Replacements
# {'atypical'}
# Potential Spelling Error:
# rashes
# Replacements
# {'rashes'}
# Potential Spelling Error:
# fatigue
# Replacements
# {'fatigue'}
# Potential Spelling Error:
# eye
# Replacements
# {'eye'}
# Potential Spelling Error:
# oral
# Replacements
# {'oral'}
# Potential Spelling Error:
# mucosa
# Replacements
# {'mucosa'}
# Potential Spelling Error:
# was
# Replacements
# {'was'}
# Potential Spelling Error:
# pink
# Replacements
# {'pink'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# moist
# Replacements
# {'moist'}
# Potential Spelling Error:
# without
# Replacements
# {'without'}
# Potential Spelling Error:
# lesions
# Replacements
# {'lesions'}
# Potential Spelling Error:
# tonsils
# Replacements
# {'tonsils'}
# Potential Spelling Error:
# were
# Replacements
# {'were'}
# Potential Spelling Error:
# not
# Replacements
# {'not'}
# Potential Spelling Error:
# enlarged
# Replacements
# {'enlarged'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# pharynx
# Replacements
# {'phalanx', 'larynx'}
# Potential Spelling Error:
# was
# Replacements
# {'was'}
# Potential Spelling Error:
# negative
# Replacements
# {'negative'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# exudates
# Replacements
# {'exudes', 'educates', 'equates'}
# Potential Spelling Error:
# lesions
# Replacements
# {'lesions'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# cervical
# Replacements
# {'cervical'}
# Potential Spelling Error:
# region
# Replacements
# {'region'}
# Potential Spelling Error:
# axillary
# Replacements
# {'axillary'}
# Potential Spelling Error:
# region
# Replacements
# {'region'}
# Potential Spelling Error:
# region
# Replacements
# {'region'}
# Potential Spelling Error:
# upon
# Replacements
# {'upon'}
# Potential Spelling Error:
# examination
# Replacements
# {'examination'}
# Potential Spelling Error:
# his
# Replacements
# {'his'}
# Potential Spelling Error:
# abdomen
# Replacements
# {'abdomen'}
# Potential Spelling Error:
# appears
# Replacements
# {'appears'}
# Potential Spelling Error:
# symmetric
# Replacements
# {'symmetric'}
# Potential Spelling Error:
# without
# Replacements
# {'without'}
# Potential Spelling Error:
# scars
# Replacements
# {'scars'}
# Potential Spelling Error:
# bowel
# Replacements
# {'bowel'}
# Potential Spelling Error:
# sounds
# Replacements
# {'sounds'}
# Potential Spelling Error:
# are
# Replacements
# {'are'}
# Potential Spelling Error:
# present
# Replacements
# {'present'}
# Potential Spelling Error:
# soft
# Replacements
# {'soft'}
# Potential Spelling Error:
# non
# Replacements
# {'non'}
# Potential Spelling Error:
# distended
# Replacements
# {'distended'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# non
# Replacements
# {'non'}
# Potential Spelling Error:
# tender
# Replacements
# {'tender'}
# Potential Spelling Error:
# abdomen
# Replacements
# {'abdomen'}
# Potential Spelling Error:
# was
# Replacements
# {'was'}
# Potential Spelling Error:
# positive
# Replacements
# {'positive'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# angle
# Replacements
# {'angle'}
# Potential Spelling Error:
# tenderness
# Replacements
# {'tenderness'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# his
# Replacements
# {'his'}
# Potential Spelling Error:
# thoracic
# Replacements
# {'thoracic'}
# Potential Spelling Error:
# his
# Replacements
# {'his'}
# Potential Spelling Error:
# mid
# Replacements
# {'mid'}
# Potential Spelling Error:
# thoracic
# Replacements
# {'thoracic'}
# Potential Spelling Error:
# tender
# Replacements
# {'tender'}
# Potential Spelling Error:
# percussion
# Replacements
# {'percussion'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# also
# Replacements
# {'also'}
# Potential Spelling Error:
# had
# Replacements
# {'had'}
# Potential Spelling Error:
# positive
# Replacements
# {'positive'}
# Potential Spelling Error:
# lloyd
# Replacements
# {'lloyd'}
# Potential Spelling Error:
# sign
# Replacements
# {'sign'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# left
# Replacements
# {'left'}
# Potential Spelling Error:
# testing
# Replacements
# {'testing'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# lab
# Replacements
# {'lab'}
# Potential Spelling Error:
# work
# Replacements
# {'work'}
# Potential Spelling Error:
# that
# Replacements
# {'that'}
# Potential Spelling Error:
# ordered
# Replacements
# {'ordered'}
# Potential Spelling Error:
# demonstrated
# Replacements
# {'demonstrated'}
# Potential Spelling Error:
# elevated
# Replacements
# {'elevated'}
# Potential Spelling Error:
# calcium
# Replacements
# {'calcium'}
# Potential Spelling Error:
# level
# Replacements
# {'level'}
# Potential Spelling Error:
# red
# Replacements
# {'red'}
# Potential Spelling Error:
# blood
# Replacements
# {'blood'}
# Potential Spelling Error:
# cells
# Replacements
# {'cells'}
# Potential Spelling Error:
# were
# Replacements
# {'were'}
# Potential Spelling Error:
# present
# Replacements
# {'present'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# urine
# Replacements
# {'urine'}
# Potential Spelling Error:
# scan
# Replacements
# {'scan'}
# Potential Spelling Error:
# did
# Replacements
# {'did'}
# Potential Spelling Error:
# show
# Replacements
# {'show'}
# Potential Spelling Error:
# stone
# Replacements
# {'stone'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# left
# Replacements
# {'left'}
# Potential Spelling Error:
# renal
# Replacements
# {'renal'}
# Potential Spelling Error:
# pelvis
# Replacements
# {'pelvis'}
# Potential Spelling Error:
# stone
# Replacements
# {'stone'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# left
# Replacements
# {'left'}
# Potential Spelling Error:
# ureter
# Replacements
# {'bremer', 'teeter', 'greater', 'peter', 'crater', 'deter', 'writer', 'preterm', 'beter', 'grater', 'jeter', 'ulster', 'dieter', 'pieter', 'quieter', 'renter', 'greeter', 'freer', 'brewer', 'meter', 'remer', 'greer', 'utter', 'urethra', 'prefer', 'exeter', 'refer', 'rester', 'unter'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# junction
# Replacements
# {'junction'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# incidental
# Replacements
# {'incidental'}
# Potential Spelling Error:
# finding
# Replacements
# {'finding'}
# Potential Spelling Error:
# mass
# Replacements
# {'mass'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# left
# Replacements
# {'left'}
# Potential Spelling Error:
# kidney
# Replacements
# {'kidney'}
# Potential Spelling Error:
# summary
# Replacements
# {'summary'}
# Potential Spelling Error:
# sabin
# Replacements
# {'cabin', 'satin', 'sarin', 'sabine', 'sabian', 'sayin'}
# Potential Spelling Error:
# suffering
# Replacements
# {'suffering'}
# Potential Spelling Error:
# from
# Replacements
# {'from'}
# Potential Spelling Error:
# kidney
# Replacements
# {'kidney'}
# Potential Spelling Error:
# stones
# Replacements
# {'stones'}
# Potential Spelling Error:
# mass
# Replacements
# {'mass'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# left
# Replacements
# {'left'}
# Potential Spelling Error:
# kidney
# Replacements
# {'kidney'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# ureter
# Replacements
# {'bremer', 'teeter', 'greater', 'peter', 'crater', 'deter', 'writer', 'preterm', 'beter', 'grater', 'jeter', 'ulster', 'dieter', 'pieter', 'quieter', 'renter', 'greeter', 'freer', 'brewer', 'meter', 'remer', 'greer', 'utter', 'urethra', 'prefer', 'exeter', 'refer', 'rester', 'unter'}
# Potential Spelling Error:
# kidney
# Replacements
# {'kidney'}
# Potential Spelling Error:
# stones
# Replacements
# {'stones'}
# Potential Spelling Error:
# are
# Replacements
# {'are'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# ureter
# Replacements
# {'bremer', 'teeter', 'greater', 'peter', 'crater', 'deter', 'writer', 'preterm', 'beter', 'grater', 'jeter', 'ulster', 'dieter', 'pieter', 'quieter', 'renter', 'greeter', 'freer', 'brewer', 'meter', 'remer', 'greer', 'utter', 'urethra', 'prefer', 'exeter', 'refer', 'rester', 'unter'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# kidney
# Replacements
# {'kidney'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# mass
# Replacements
# {'mass'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# kidney
# Replacements
# {'kidney'}
# Potential Spelling Error:
# clear
# Replacements
# {'clear'}
# Potential Spelling Error:
# finding
# Replacements
# {'finding'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# mass
# Replacements
# {'mass'}
# Potential Spelling Error:
# likely
# Replacements
# {'likely'}
# Potential Spelling Error:
# contributing
# Replacements
# {'contributing'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# calcium
# Replacements
# {'calcium'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# therefore
# Replacements
# {'therefore'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# stone
# Replacements
# {'stone'}
# Potential Spelling Error:
# formation
# Replacements
# {'formation'}
# Potential Spelling Error:
# are
# Replacements
# {'are'}
# Potential Spelling Error:
# ordering
# Replacements
# {'ordering'}
# Potential Spelling Error:
# repeat
# Replacements
# {'repeat'}
# Potential Spelling Error:
# bmp
# Replacements
# {'amp', 'bup', 'bap', 'ump', 'emp', 'bop', 'imp', 'bump', 'bip'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# ray
# Replacements
# {'ray'}
# Potential Spelling Error:
# kidney
# Replacements
# {'kidney'}
# Potential Spelling Error:
# ureter
# Replacements
# {'bremer', 'teeter', 'greater', 'peter', 'crater', 'deter', 'writer', 'preterm', 'beter', 'grater', 'jeter', 'ulster', 'dieter', 'pieter', 'quieter', 'renter', 'greeter', 'freer', 'brewer', 'meter', 'remer', 'greer', 'utter', 'urethra', 'prefer', 'exeter', 'refer', 'rester', 'unter'}
# Potential Spelling Error:
# bladder
# Replacements
# {'bladder'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# were
# Replacements
# {'were'}
# Potential Spelling Error:
# going
# Replacements
# {'going'}
# Potential Spelling Error:
# also
# Replacements
# {'also'}
# Potential Spelling Error:
# order
# Replacements
# {'order'}
# Potential Spelling Error:
# ekg
# Replacements
# {'ekg'}
# Potential Spelling Error:
# are
# Replacements
# {'are'}
# Potential Spelling Error:
# putting
# Replacements
# {'putting'}
# Potential Spelling Error:
# him
# Replacements
# {'him'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# pain
# Replacements
# {'pain'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# zoltan
# Replacements
# {'zoltan'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# nausea
# Replacements
# {'nausea'}
# Potential Spelling Error:
# zofran
# Replacements
# {'zoltan', 'ofan', 'goran', 'foran', 'zorin', 'zorn', 'fran', 'moran'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# hes
# Replacements
# {'hes'}
# Potential Spelling Error:
# going
# Replacements
# {'going'}
# Potential Spelling Error:
# normal
# Replacements
# {'normal'}
# Potential Spelling Error:
# diet
# Replacements
# {'diet'}
# Potential Spelling Error:
# activity
# Replacements
# {'activity'}
# Potential Spelling Error:
# tolerated
# Replacements
# {'tolerated'}
# Potential Spelling Error:
# addition
# Replacements
# {'addition'}
# Potential Spelling Error:
# consulting
# Replacements
# {'consulting'}
# Potential Spelling Error:
# oncology
# Replacements
# {'oncology'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# mass
# Replacements
# {'mass'}
# Potential Spelling Error:
# will
# Replacements
# {'will'}
# Potential Spelling Error:
# consult
# Replacements
# {'consult'}
# Potential Spelling Error:
# endocrinology
# Replacements
# {'endocrinology'}
# Potential Spelling Error:
# hospitalist
# Replacements
# {'hospitalise'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# urology
# Replacements
# {'urology'}
# Potential Spelling Error:
# hes
# Replacements
# {'hes'}
# Potential Spelling Error:
# being
# Replacements
# {'being'}
# Potential Spelling Error:
# admitted
# Replacements
# {'admitted'}
# Potential Spelling Error:
# medsurg
# Replacements
# {'measure'}
# Potential Spelling Error:
# and
# Replacements
# {'and'}
# Potential Spelling Error:
# the
# Replacements
# {'the'}
# Potential Spelling Error:
# patient
# Replacements
# {'patient'}
# Potential Spelling Error:
# has
# Replacements
# {'has'}
# Potential Spelling Error:
# been
# Replacements
# {'been'}
# Potential Spelling Error:
# educated
# Replacements
# {'educated'}
# Potential Spelling Error:
# his
# Replacements
# {'his'}
# Potential Spelling Error:
# plan
# Replacements
# {'plan'}
# Potential Spelling Error:
# you
# Replacements
# {'you'}
# Potential Spelling Error:
# have
# Replacements
# {'have'}
# Potential Spelling Error:
# any
# Replacements
# {'any'}
# Potential Spelling Error:
# further
# Replacements
# {'further'}
# Potential Spelling Error:
# questions
# Replacements
# {'questions'}
# Potential Spelling Error:
# for
# Replacements
# {'for'}

# %%
unkn
# Out:
# ['clopidogrel',
#  'lisinopril',
#  'tonsillar',
#  'lymphadenopathy',
#  'auscultation',
#  'hepatosplenomegaly',
#  'hematuria',
#  'dysmorphic',
#  'esterase',
#  'proteinuria',
#  'cardiomegaly',
#  'dysphagia',
#  'hematuria',
#  'glomerulonephritis',
#  'spirometry',
#  'lisinopril',
#  'clopidogrel',
#  'labetalol',
#  'hyperlipidemia',
#  'simvastatin',
#  'hypothyroidism',
#  'levothyroxine',
#  'simvastatin',
#  'hyperlipidemia',
#  'rhabdomyolysis',
#  'hyperkalemia',
#  'spirometry',
#  'simvastatin',
#  'gluconate',
#  'intensivist',
#  'hematuria',
#  'cystoscopy',
#  'urothelial',
#  'dysuria',
#  'orthopnea',
#  'hematuria',
#  'polyuria',
#  'oliguria',
#  'dysuria',
#  'apixaban',
#  'lisinopril',
#  'budesonide',
#  'formoterol',
#  'lymphadenopathy',
#  'auscultation',
#  'urothelial',
#  'hematuria',
#  'apixaban',
#  'lisinopril',
#  'budesonide',
#  'suprapubic',
#  'urothelial',
#  'lisinopril',
#  'apixaban',
#  'budesonide',
#  'formoterol',
#  'suprapubic',
#  'oropharynx',
#  'tonsillar',
#  'lymphadenopathy',
#  'urothelial',
#  'urothelial',
#  'hematuria',
#  'apixaban',
#  'urothelial',
#  'hypothyroidism',
#  'levothyroxine',
#  'simvastatin',
#  'levothyroxine',
#  'pyelonephritis',
#  'rhabdomyolysis',
#  'hyperuricemia',
#  'hyperkalemia',
#  'hyperphosphatemia',
#  'myoglobinuria',
#  'myoglobinuria',
#  'gluconate',
#  'hyperkalemia',
#  'simvastatin',
#  'intensivist',
#  'suprapubic',
#  'lisinopril',
#  'apixaban',
#  'suprapubic',
#  'urothelial',
#  'urothelial',
#  'lisinopril',
#  'myalgias',
#  'hyperlipidemia',
#  'simvastatin',
#  'hypothyroidism',
#  'levothyroxine',
#  'hematuria',
#  'myalgias',
#  'rhabdomyolysis',
#  'hyperkalemia',
#  'hematuria',
#  'rhabdomyolysis',
#  'hyperkalemia',
#  'gluconate',
#  'levothyroxine',
#  'simvastatin',
#  'myotoxicity',
#  'afternoon',
#  'hyperlipidemia',
#  'hypothyroidism',
#  'hyperlipidemia',
#  'levothyroxine',
#  'simvastatin',
#  'oropharynx',
#  'tonsillar',
#  'lymphadenopathy',
#  'auscultation',
#  'hyperkalemia',
#  'hyperkalemia',
#  'hyperkalemia',
#  'rhabdomyolysis',
#  'spirometry',
#  'gluconate',
#  'intensivist',
#  'afternoon',
#  'dysuria',
#  'hyperlipidemia',
#  'simvastatin',
#  'hypothyroidism',
#  'levothyroxine',
#  'pneumovax',
#  'esterase',
#  'esterase',
#  'pathophysiology',
#  'rhabdomyolysis',
#  'simvastatin',
#  'gluconate',
#  'intensivist',
#  'hematuria',
#  'lisinopril',
#  'clopidogrel',
#  'electrocardiogram',
#  'radiographic',
#  'cardiomegaly',
#  'tonsillar',
#  'oropharyngeal',
#  'dismorphic',
#  'electrocardiographic',
#  'discontinuation',
#  'lisinopril',
#  'clopidogrel',
#  'labetalol',
#  'symptomology',
#  'glomerulonephritis',
#  'underscoring',
#  'lipidemia',
#  'simvastatin',
#  'hypothyroidism',
#  'synthroid',
#  'myalgias',
#  'myalgias',
#  'myalgias',
#  'levothyroxine',
#  'hyperlipidemia',
#  'myalgias',
#  'arthralgias',
#  'suprapubic',
#  'rhabdomyolysis',
#  'hyperkalemia',
#  'rhabdomyolysis',
#  'hyperkalemia',
#  'rhabdomyolysis',
#  'hyperkalemia',
#  'hyperlipidemia',
#  'hypothyroidism',
#  '500cc',
#  'simvastatin',
#  'gluconate',
#  'hyperkalemia',
#  'spirometry',
#  'hydrochlorothiazide',
#  'polyurea',
#  'suprapubic',
#  'lymphadenopathy',
#  'auscultation',
#  'nephrolithiasis',
#  'hydrochlorothiazide',
#  'ondansetron',
#  'ketorolac',
#  'calcitonin',
#  'afternoon',
#  'hematuria',
#  'hematuria',
#  'suprapubic',
#  'urothelial',
#  'cystoscopy',
#  'tachypnea',
#  'urothelial',
#  'lisinopril',
#  'budesonide',
#  'cystoscopy',
#  'urothelial',
#  'suprapubic',
#  'musculoskeletal',
#  'auscultation',
#  'auscultation',
#  'suprapubic',
#  'oropharynx',
#  'erythematous',
#  'hematuria',
#  'urothelial',
#  'hematuria',
#  'hematuria',
#  'hydrochlorothiazide',
#  'nephrolithiasis',
#  'hypercalcemia',
#  'spirometry',
#  'hydrochlorothiazide',
#  'ketorolac',
#  'calcitonin',
#  'odynophagia',
#  'hematuria',
#  'clopidogrel',
#  'shingrix',
#  'pneumovax',
#  'dysphagia',
#  'hematuria',
#  'erythematous',
#  'oropharynx',
#  'tonsillar',
#  'lymphadenopathy',
#  'auscultation',
#  'suprapubic',
#  'esterase',
#  'proteinuria',
#  'hematuria',
#  'glomerulonephritis',
#  'glomerulonephritis',
#  'nephritis',
#  'spirometry',
#  'lisinopril',
#  'clopidogrel',
#  'labetalol',
#  'clopidogrel',
#  'lisinopril',
#  'oropharynx',
#  'tonsillar',
#  'lymphadenopathy',
#  'auscultation',
#  'auscultation',
#  'cardiomegaly',
#  'dysmorphic',
#  'glomerulonephritis',
#  'lisinopril',
#  'clopidogrel',
#  'clopidogrel',
#  'labetalol',
#  'hydrochlorothiazide',
#  'lymphadenopathy',
#  'supraclavicular',
#  'costovertebral',
#  'ureteropelvic',
#  'calcitonin',
#  'ketorolac']

# %%
len(unkn)
# Out:
# 260

# %%
res = [i for n, i in enumerate(unkn) if i not in unkn[:n]]
res
# Out:
# ['clopidogrel',
#  'lisinopril',
#  'tonsillar',
#  'lymphadenopathy',
#  'auscultation',
#  'hepatosplenomegaly',
#  'hematuria',
#  'dysmorphic',
#  'esterase',
#  'proteinuria',
#  'cardiomegaly',
#  'dysphagia',
#  'glomerulonephritis',
#  'spirometry',
#  'labetalol',
#  'hyperlipidemia',
#  'simvastatin',
#  'hypothyroidism',
#  'levothyroxine',
#  'rhabdomyolysis',
#  'hyperkalemia',
#  'gluconate',
#  'intensivist',
#  'cystoscopy',
#  'urothelial',
#  'dysuria',
#  'orthopnea',
#  'polyuria',
#  'oliguria',
#  'apixaban',
#  'budesonide',
#  'formoterol',
#  'suprapubic',
#  'oropharynx',
#  'pyelonephritis',
#  'hyperuricemia',
#  'hyperphosphatemia',
#  'myoglobinuria',
#  'myalgias',
#  'myotoxicity',
#  'afternoon',
#  'pneumovax',
#  'pathophysiology',
#  'electrocardiogram',
#  'radiographic',
#  'oropharyngeal',
#  'dismorphic',
#  'electrocardiographic',
#  'discontinuation',
#  'symptomology',
#  'underscoring',
#  'lipidemia',
#  'synthroid',
#  'arthralgias',
#  '500cc',
#  'hydrochlorothiazide',
#  'polyurea',
#  'nephrolithiasis',
#  'ondansetron',
#  'ketorolac',
#  'calcitonin',
#  'tachypnea',
#  'musculoskeletal',
#  'erythematous',
#  'hypercalcemia',
#  'odynophagia',
#  'shingrix',
#  'nephritis',
#  'supraclavicular',
#  'costovertebral',
#  'ureteropelvic']

# %%
len(res)
# Out:
# 71

# %%
res
# Out:
# ['clopidogrel',
#  'lisinopril',
#  'tonsillar',
#  'lymphadenopathy',
#  'auscultation',
#  'hepatosplenomegaly',
#  'hematuria',
#  'dysmorphic',
#  'esterase',
#  'proteinuria',
#  'cardiomegaly',
#  'dysphagia',
#  'glomerulonephritis',
#  'spirometry',
#  'labetalol',
#  'hyperlipidemia',
#  'simvastatin',
#  'hypothyroidism',
#  'levothyroxine',
#  'rhabdomyolysis',
#  'hyperkalemia',
#  'gluconate',
#  'intensivist',
#  'cystoscopy',
#  'urothelial',
#  'dysuria',
#  'orthopnea',
#  'polyuria',
#  'oliguria',
#  'apixaban',
#  'budesonide',
#  'formoterol',
#  'suprapubic',
#  'oropharynx',
#  'pyelonephritis',
#  'hyperuricemia',
#  'hyperphosphatemia',
#  'myoglobinuria',
#  'myalgias',
#  'myotoxicity',
#  'afternoon',
#  'pneumovax',
#  'pathophysiology',
#  'electrocardiogram',
#  'radiographic',
#  'oropharyngeal',
#  'dismorphic',
#  'electrocardiographic',
#  'discontinuation',
#  'symptomology',
#  'underscoring',
#  'lipidemia',
#  'synthroid',
#  'arthralgias',
#  '500cc',
#  'hydrochlorothiazide',
#  'polyurea',
#  'nephrolithiasis',
#  'ondansetron',
#  'ketorolac',
#  'calcitonin',
#  'tachypnea',
#  'musculoskeletal',
#  'erythematous',
#  'hypercalcemia',
#  'odynophagia',
#  'shingrix',
#  'nephritis',
#  'supraclavicular',
#  'costovertebral',
#  'ureteropelvic']

# %%
from textblob import TextBlob
def secondSpell(unknown_list):
    for a in unknown_list:
        print("original text: "+str(a))
        b = TextBlob(a)
        print("corrected text: "+str(b.correct()))

# %%
secondSpell(res)
# Out:
# original text: clopidogrel
# corrected text: clopidogrel
# original text: lisinopril
# corrected text: lisinopril
# original text: tonsillar
# corrected text: tonsillar
# original text: lymphadenopathy
# corrected text: lymphadenopathy
# original text: auscultation
# corrected text: auscultation
# original text: hepatosplenomegaly
# corrected text: hepatosplenomegaly
# original text: hematuria
# corrected text: haematuria
# original text: dysmorphic
# corrected text: dysmorphic
# original text: esterase
# corrected text: esterase
# original text: proteinuria
# corrected text: proteinuria
# original text: cardiomegaly
# corrected text: cardiomegaly
# original text: dysphagia
# corrected text: dysphagia
# original text: glomerulonephritis
# corrected text: glomerulonephritis
# original text: spirometry
# corrected text: spirometry
# original text: labetalol
# corrected text: labetalol
# original text: hyperlipidemia
# corrected text: hyperlipidemia
# original text: simvastatin
# corrected text: simvastatin
# original text: hypothyroidism
# corrected text: hypothyroidism
# original text: levothyroxine
# corrected text: levothyroxine
# original text: rhabdomyolysis
# corrected text: rhabdomyolysis
# original text: hyperkalemia
# corrected text: hyperaemia
# original text: gluconate
# corrected text: gluconate
# original text: intensivist
# corrected text: intensivist
# original text: cystoscopy
# corrected text: cystoscopy
# original text: urothelial
# corrected text: urothelial
# original text: dysuria
# corrected text: dysuria
# original text: orthopnea
# corrected text: orthopnea
# original text: polyuria
# corrected text: polyuria
# original text: oliguria
# corrected text: oliguria
# original text: apixaban
# corrected text: apixaban
# original text: budesonide
# corrected text: budesonide
# original text: formoterol
# corrected text: formoterol
# original text: suprapubic
# corrected text: suprapubic
# original text: oropharynx
# corrected text: oropharynx
# original text: pyelonephritis
# corrected text: pyelonephritis
# original text: hyperuricemia
# corrected text: hyperuricemia
# original text: hyperphosphatemia
# corrected text: hyperphosphatemia
# original text: myoglobinuria
# corrected text: myoglobinuria
# original text: myalgias
# corrected text: myalgias
# original text: myotoxicity
# corrected text: myotoxicity
# original text: afternoon
# corrected text: afternoon
# original text: pneumovax
# corrected text: pneumovax
# original text: pathophysiology
# corrected text: pathophysiology
# original text: electrocardiogram
# corrected text: electrocardiogram
# original text: radiographic
# corrected text: radiographic
# original text: oropharyngeal
# corrected text: oropharyngeal
# original text: dismorphic
# corrected text: dismorphic
# original text: electrocardiographic
# corrected text: electrocardiographic
# original text: discontinuation
# corrected text: discontinuation
# original text: symptomology
# corrected text: symptomology
# original text: underscoring
# corrected text: underscoring
# original text: lipidemia
# corrected text: lipidemia
# original text: synthroid
# corrected text: synthroid
# original text: arthralgias
# corrected text: arthralgia
# original text: 500cc
# corrected text: 500cc
# original text: hydrochlorothiazide
# corrected text: hydrochlorothiazide
# original text: polyurea
# corrected text: polyurea
# original text: nephrolithiasis
# corrected text: nephrolithiasis
# original text: ondansetron
# corrected text: ondansetron
# original text: ketorolac
# corrected text: ketorolac
# original text: calcitonin
# corrected text: calcitonin
# original text: tachypnea
# corrected text: tachypnea
# original text: musculoskeletal
# corrected text: musculoskeletal
# original text: erythematous
# corrected text: erythematous
# original text: hypercalcemia
# corrected text: hypercalcemia
# original text: odynophagia
# corrected text: odynophagia
# original text: shingrix
# corrected text: shingrix
# original text: nephritis
# corrected text: nephritis
# original text: supraclavicular
# corrected text: supraclavicular
# original text: costovertebral
# corrected text: costovertebral
# original text: ureteropelvic
# corrected text: ureteropelvic

# %%
print(spell.candidates('zoltan'))
# Out:
# {'zoltan'}

# %%
def clean(x):
    clean =[]
    for i in x:
        i=i.lower()
        j=remove_punctuations(i)
        clean.append(j)
    return clean

# %%
#data1['clean']= clean(data1['Responses'])
#data1['doc_len'] = data1["clean"].apply(lambda i: len(i.split()))

# %%
import nltk
#nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download("stopwords",quiet=True)
nltk.download('punkt',quiet=True)
nltk.download('wordnet',quiet=True)
nltk.download('omw-1.4',quiet=True)
#remove common words from data
stop = stopwords.words('english')
stop.remove('no')
stop.remove('not')
stop.remove('most')
stop.remove('some')
stop.remove('out')
print(stop)
data1['clean'] =data1['Responses'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
data1['clean']
data1['clean']= clean(data1['clean'])
data1['clean'] =data1['clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
data1['doc_len'] = data1["clean"].apply(lambda i: len(i.split()))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'other', 'such', 'nor', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
data1['clean']
# Out:
# 0     student doctor presenting patient mrs sabin 66...
# 1     64 year old female presents emergency departme...
# 2     hi name student doctor today im giving case pr...
# 3     hello presenting today patient alex sabin hes ...
# 4     hello dr rawlins came room 8 went 64 year old ...
# 5     hello case presentation alex sabin 65 year old...
# 6     hi dr rollins id like present mrs sabin shes 6...
# 7     good afternoon patient today alex savin 64 yea...
# 8     student dr reporting alex sabin mrs sabin 64 y...
# 9     okay met mr alex 66 year old male presents chi...
# 10    hey dr smith got finished seeing alex sabin sh...
# 11    mrs alex sabin 67 year old english professor h...
# 12    good afternoon dr rollins pleasure seeing alex...
# 13    mrs alex sabin 67 year old female presents com...
# 14    mrs sabin 66 year old retired professor presen...
# 15    patient retired 66 year old man presents one w...
# 16    mr alex sabin 67 year old male past medical hi...
# Name: clean, dtype: object

# %%
data1['doc_len']
# Out:
# 0     476
# 1     208
# 2     382
# 3     383
# 4     363
# 5     156
# 6     323
# 7     425
# 8     212
# 9     258
# 10    412
# 11    287
# 12    301
# 13    354
# 14    460
# 15    356
# 16    319
# Name: doc_len, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15, 5))
sns.histplot(data1['doc_len']).set(title='Detail Document Length', xlabel='Document Length', ylabel='Count')
print(round(np.mean(data1['doc_len'])),round(np.std(data1['doc_len'])))
# Out:
# 334 87

# %%
def word_count(str):
    counts = dict()
    words = str.split()

    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    return counts

# %%
def bag_of_words(X):
    bag=""
    for i in X:
        bag = bag + " " + i
    return bag

# %%
bag=bag_of_words(data1["clean"])
len(bag)
# Out:
# 41284

# %%
import itertools
from operator import itemgetter, attrgetter
from sklearn.feature_extraction import DictVectorizer
fig, ax = plt.subplots(figsize=(15, 15))
plt.rcParams.update({'font.size':20})
sns.set_style('darkgrid')
nlp_words=sorted(word_count(bag).items(),key=itemgetter(1),reverse=True)
print("Number of Unique Words")
print(len(nlp_words))
x,y = zip(*nlp_words)
plt.plot(x[0:30],y[0:30])
plt.title('Word Frequency: Limited to 30 Words'), 
plt.xlabel('Word')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# Number of Unique Words
# 1444

# %%
def get_topics(components,vocab):
    topic_word_list = []
    sorted_terms=[]
    for i, comp in enumerate(components):
        terms_comp = zip(vocab,comp)
        st = sorted(terms_comp, key= lambda x:x[1], reverse=True)[:7]
        sorted_terms.append(st)
    topic=" "
    for t in sorted_terms:
        topic=''
        for k in t:
            topic= topic + ' ' + k[0]
        topic_word_list.append(topic)
    return topic_word_list

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
tfidvec = TfidfVectorizer(min_df = 2,
                          max_df = 0.95,
                          norm = 'l2',
                          stop_words = 'english')
TFIDF = tfidvec.fit_transform(data1['clean'])
TFIDF
# Out:
# <17x717 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3072 stored elements in Compressed Sparse Row format>

# %%
tfidf_tokens = tfidvec.get_feature_names_out()
tfidf_tokens
# Out:
# array(['10', '100', '1015', '105', '13', '135', '139', '15', '160', '18',
#        '185', '20', '25', '30', '31', '50', '500', '60', '64', '65', '66',
#        '67', '75', '82', '83', '85', '86', '90', '92', '95', '986',
#        'abdomen', 'abdominal', 'accident', 'acetaminophen', 'aches',
#        'acid', 'acidic', 'active', 'activity', 'acute', 'addition',
#        'additional', 'additionally', 'admit', 'admits', 'admitted',
#        'admitting', 'afternoon', 'age', 'agent', 'ago', 'agreement',
#        'ahead', 'alcohol', 'alcoholic', 'alert', 'alex', 'alive',
#        'allergic', 'allergies', 'allergy', 'alleviate', 'allowed', 'alt',
#        'ambulatory', 'amoxicillin', 'amp', 'angle', 'anterior',
#        'apixaban', 'appears', 'appendectomy', 'approximately', 'artery',
#        'aso', 'assessment', 'ast', 'atrial', 'auscultation', 'awake',
#        'away', 'axis', 'bag', 'balanced', 'basic', 'beats', 'began',
#        'believe', 'beverages', 'bicarb', 'bicarbonate', 'bilateral',
#        'bilaterally', 'bladder', 'bleeding', 'block', 'bloody', 'bmp',
#        'bnp', 'body', 'bowel', 'branch', 'breath', 'breathing', 'brown',
#        'budesonide', 'bun', 'bundle', 'caffeine', 'calcitonin', 'calcium',
#        'calf', 'calves', 'came', 'cancer', 'cannula', 'carcinoma',
#        'cardiac', 'cardiomegaly', 'cardiovascular', 'care', 'case',
#        'catheter', 'cbc', 'cell', 'cells', 'cerebral', 'cervical',
#        'change', 'changes', 'chart', 'checks', 'chest', 'chief', 'chills',
#        'ck', 'clear', 'clopidogrel', 'cmp', 'coffee', 'college',
#        'colonoscopy', 'color', 'colored', 'come', 'compartment',
#        'complaining', 'complaint', 'complement', 'compliant', 'concern',
#        'concerned', 'concerns', 'condition', 'confirmed', 'consistent',
#        'constant', 'consult', 'consulted', 'consumption', 'continue',
#        'continued', 'contrast', 'cool', 'copd', 'cough', 'coughing',
#        'counseled', 'couple', 'creatinine', 'ct', 'culture', 'cups',
#        'current', 'currently', 'cystoscopy', 'd50', 'daily', 'dark',
#        'date', 'day', 'days', 'deceased', 'decreased', 'deferred',
#        'degrees', 'demonstrate', 'demonstrated', 'denied', 'denies',
#        'department', 'describes', 'diagnosed', 'diagnosis', 'diagnostic',
#        'diarrhea', 'died', 'diet', 'diff', 'differential', 'difficulty',
#        'discharge', 'discomfort', 'discontinue', 'distended',
#        'distension', 'distress', 'doctor', 'dr', 'drank', 'drinking',
#        'drinks', 'drug', 'drugs', 'dull', 'dvt', 'dysmorphic',
#        'dysphagia', 'dysuria', 'eating', 'eats', 'ed', 'edema', 'ekg',
#        'electrolyte', 'electrolytes', 'elevated', 'emergency', 'end',
#        'endocrinology', 'endorses', 'enlarged', 'episode', 'er',
#        'erythema', 'erythematous', 'especially', 'esr', 'esterase',
#        'evaluation', 'exam', 'examination', 'excuse', 'exercise',
#        'experiencing', 'exposed', 'exposure', 'extremities', 'extremity',
#        'exudate', 'exudates', 'fahrenheit', 'family', 'far', 'farm',
#        'father', 'fatigue', 'fatigued', 'female', 'fever', 'fibrillation',
#        'findings', 'flank', 'fluids', 'foley', 'follow', 'following',
#        'formoterol', 'frequency', 'frequently', 'fullness', 'function',
#        'gain', 'gallop', 'gallops', 'gas', 'general', 'generally',
#        'genital', 'getting', 'gi', 'given', 'giving', 'glass', 'glasses',
#        'glomerulonephritis', 'gluconate', 'going', 'good', 'got',
#        'gotten', 'groin', 'group', 'gu', 'guarding', 'half', 'head',
#        'health', 'healthy', 'heart', 'heent', 'hello', 'help',
#        'hematuria', 'hes', 'hi', 'high', 'highly', 'home', 'hospitalist',
#        'hospitalists', 'hospitalizations', 'hour', 'hours', 'husband',
#        'hydrated', 'hydrochlorothiazide', 'hyper', 'hyperkalemia',
#        'hyperlipidemia', 'hypertension', 'hypertensive', 'hypothyroidism',
#        'icu', 'id', 'illicit', 'im', 'imaging', 'immunizations',
#        'incentive', 'incidental', 'include', 'includes', 'increased',
#        'indicated', 'indicating', 'infection', 'injury', 'instructions',
#        'insulin', 'insurance', 'intact', 'intake', 'intensivist',
#        'interested', 'interventions', 'iv', 'ive', 'junction',
#        'ketorolac', 'kidney', 'kinase', 'know', 'known', 'kub', 'lab',
#        'labetalol', 'labs', 'lactate', 'lactated', 'lasix', 'led', 'left',
#        'leg', 'lesions', 'let', 'level', 'levels', 'levothyroxine',
#        'light', 'like', 'likely', 'limits', 'lisinopril', 'liters',
#        'liver', 'lives', 'living', 'lloyd', 'look', 'looks', 'loss',
#        'low', 'lower', 'lung', 'lungs', 'lymphadenopathy', 'lysis',
#        'male', 'marathon', 'mass', 'maternal', 'medical', 'medication',
#        'medications', 'mentioned', 'metabolic', 'mg', 'micrograms',
#        'microscopic', 'microscopy', 'mid', 'midline', 'mild', 'miles',
#        'military', 'milligrams', 'milliliters', 'millimeter', 'minute',
#        'miss', 'moderate', 'moist', 'monitored', 'monogamous', 'morning',
#        'mother', 'motion', 'mouth', 'movement', 'mr', 'mri', 'mrs', 'msk',
#        'mucosa', 'murmur', 'murmurs', 'muscle', 'muscles', 'muscularis',
#        'myalgias', 'nasal', 'nausea', 'necessary', 'neck', 'need',
#        'needed', 'negative', 'nephrolithiasis', 'nephrologist', 'neuro',
#        'neurovascular', 'night', 'non', 'normal', 'normalize', 'note',
#        'noted', 'notes', 'notice', 'nuchal', 'nurse', 'nursing', 'o2',
#        'omm', 'oncologist', 'oncology', 'onset', 'oral', 'orange',
#        'order', 'ordered', 'ordering', 'orders', 'oriented', 'oropharynx',
#        'os', 'osculation', 'osteopathic', 'output', 'overall', 'oxygen',
#        'pack', 'pain', 'palpation', 'palpitations', 'panel', 'pass',
#        'past', 'patient', 'patients', 'peaked', 'pelvis', 'percussion',
#        'pertinent', 'pharyngeal', 'pharynx', 'phosphate', 'phosphorous',
#        'phosphorus', 'physical', 'pink', 'pitting', 'placed', 'placement',
#        'plan', 'plus', 'pneumovax', 'po', 'positive', 'positives',
#        'possibly', 'post', 'posterior', 'potassium', 'pounds', 'present',
#        'presentation', 'presented', 'presenting', 'presents', 'pressure',
#        'prior', 'probably', 'procedures', 'professor', 'progressively',
#        'proper', 'prophylaxis', 'propria', 'protein', 'proteinuria',
#        'pulmonary', 'pulse', 'pulses', 'qrs', 'quadrants', 'questions',
#        'quitting', 'radiates', 'ran', 'range', 'rapid', 'rash', 'rashes',
#        'rate', 'rates', 'ray', 'rbcs', 'real', 'really', 'recent',
#        'recently', 'rectal', 'red', 'refer', 'referring', 'reflex',
#        'region', 'regular', 'relationship', 'relief', 'remained',
#        'remains', 'remarkable', 'renal', 'repeat', 'report', 'reported',
#        'reporting', 'reports', 'require', 'respiratory', 'results',
#        'retention', 'retired', 'revealed', 'reveals', 'review',
#        'rhabdomyolysis', 'rhythm', 'right', 'rigidity', 'ringers', 'risk',
#        'rollins', 'room', 'ros', 'sabin', 'sabins', 'saline',
#        'saturation', 'scars', 'screening', 'secondary', 'seeing',
#        'setting', 'severe', 'sharp', 'shes', 'shortness', 'showed',
#        'shows', 'sign', 'significant', 'signs', 'simvastatin', 'sinus',
#        'skin', 'smoking', 'social', 'soft', 'sore', 'sounds', 'spasms',
#        'specifically', 'spirometry', 'splenectomy', 'spo2', 'stable',
#        'start', 'started', 'stated', 'states', 'stent', 'stone', 'stones',
#        'stool', 'stop', 'strep', 'streptococcal', 'streptococcus',
#        'strict', 'stroke', 'student', 'sulfa', 'suprapubic', 'sure',
#        'surgery', 'surgical', 'suspected', 'suspicion', 'swallowing',
#        'swelling', 'symmetric', 'symptoms', 'syndrome', 'systems', 't10',
#        'tachycardia', 'tachycardic', 'takes', 'taking', 'tart',
#        'telemetry', 'temperature', 'tender', 'tenderness', 'terms',
#        'test', 'testing', 'thank', 'thats', 'theres', 'thighs', 'thing',
#        'thoracic', 'throat', 'time', 'times', 'tobacco', 'today',
#        'tolerated', 'tonsillar', 'tonsils', 'training', 'treatment',
#        'troponin', 'tumor', 'twice', 'ua', 'unremarkable', 'upper',
#        'ureter', 'urgency', 'uric', 'urinalysis', 'urinary', 'urinating',
#        'urination', 'urine', 'urologist', 'urology', 'urothelial', 'use',
#        'used', 'using', 'uvula', 'vaccinations', 'values', 'vascular',
#        'vietnam', 'vital', 'vitals', 'vomiting', 'wall', 'want', 'water',
#        'waves', 'week', 'weeks', 'weight', 'went', 'wheezing', 'whiskey',
#        'white', 'wide', 'wife', 'wine', 'woman', 'work', 'worse',
#        'worsens', 'years', 'yesterday', 'zofran'], dtype=object)

# %%
tfidf_dict = dict(zip(tfidf_tokens, TFIDF.toarray().sum(axis=0)))
# sort in descending order
tfidf_dict = dict(sorted(tfidf_dict.items(), key=lambda x: x[1], reverse=True))

# initialise dataframe
tfidf_df = pd.DataFrame.from_dict(tfidf_dict, orient='index', columns=['tfidf'])
# name the index
tfidf_df.index = tfidf_df.index.rename('token')
# display first 5 rows
tfidf_df
# Out:
#                 tfidf
# token
# patient      2.146043
# pain         1.342367
# urine        1.192135
# mrs          1.025628
# sabin        0.973977
# ...               ...
# eating       0.106211
# guarding     0.106211
# proteinuria  0.106211
# whiskey      0.106211
# following    0.104431
#
# [717 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(15, 15))
plt.rcParams.update({'font.size':20})
sns.set_style('darkgrid')
#nlp_words=sorted(word_count(bag).items(),key=itemgetter(1),reverse=True)
print("TFIDF Words")
#print(len(nlp_words))
#x,y = zip(*nlp_words)
x = tfidf_df.index
y = tfidf_df['tfidf']
plt.plot(x[0:50],y[0:50])
plt.title('Word TFIDF: Limited to 50 Words'), 
plt.xlabel('Word')
plt.ylabel('TFIDF')
plt.xticks(rotation=90)
plt.show()
# Out:
# TFIDF Words
